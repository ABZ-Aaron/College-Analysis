# %% [markdown]
# # Visualising Earnings Based On College Majors

# %% [markdown]
# This short project servers as practice for matplotlib and panda plotting functionality. Here I'll be working with a dataset on job outcomes of students who graduated between 2010-2012.

# %%
import pandas as pd

import matplotlib.pyplot as plt

from pandas.plotting import scatter_matrix

# %matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')

# %% [markdown]
# Let's start by exploring the dataset.

# %%
recent_grads.iloc[0] # Return first row formatted as table.
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  ...  \
# 168    Biology & Life Science    0.637293           47      6259  ...
# 169  Psychology & Social Work    0.817099            7      2125  ...
# 170  Psychology & Social Work    0.799859           13      2101  ...
# 171  Psychology & Social Work    0.798746           21      3777  ...
# 172                 Education    0.877960            2       742  ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads.describe(include = 'all')
# Out:
#               Rank   Major_code      Major          Total            Men  \
# count   173.000000   173.000000        173     172.000000     172.000000
# unique         NaN          NaN        173            NaN            NaN
# top            NaN          NaN  ECONOMICS            NaN            NaN
# freq           NaN          NaN          1            NaN            NaN
# mean     87.000000  3879.815029        NaN   39370.081395   16723.406977
# std      50.084928  1687.753140        NaN   63483.491009   28122.433474
# min       1.000000  1100.000000        NaN     124.000000     119.000000
# 25%      44.000000  2403.000000        NaN    4549.750000    2177.500000
# 50%      87.000000  3608.000000        NaN   15104.000000    5434.000000
# 75%     130.000000  5503.000000        NaN   38909.750000   14631.000000
# max     173.000000  6403.000000        NaN  393735.000000  173809.000000
#
#                 Women Major_category  ShareWomen  Sample_size       Employed  \
# ...

# %% [markdown]
# Let's drop any rows with missing data for this exercise.

# %%
raw_data_count = recent_grads.shape[0]

# %%
recent_grads = recent_grads.dropna()

# %%
cleaned_data_count = recent_grads.shape[0]

# %%
print(f'Raw Data: {raw_data_count:10}\nCleaned Data : {cleaned_data_count:5}')
# Out:
# Raw Data:        173
# Cleaned Data :   172

# %% [markdown]
# It looks like only one row had missing data.
#
# Now let's explore some visualisations. We'll start with scatterplots.

# %%
recent_grads.plot(kind = 'scatter', x = 'Sample_size', y= 'Median', title = "Sample Size vs. Median")
plt.show()

# %%
recent_grads.plot(kind = 'scatter', x = 'Sample_size', y = 'Unemployment_rate', title = 'Sample Size vs. Unemployment Rate')
plt.show()

# %%
recent_grads.plot(kind = 'scatter', x = 'Full_time', y = 'Median', title = 'Full Time vs. Median')
plt.show()

# %%
recent_grads.plot(kind = 'scatter', x = 'ShareWomen', y = 'Unemployment_rate', title = 'Share of Women vs. Unemployment Rate')
plt.show()

# %%
recent_grads.plot(kind = 'scatter', x = 'Men', y = 'Median', title = 'Men vs. Median')
plt.show()

# %%
recent_grads.plot(kind = 'scatter', x = 'Women', y = 'Median', title = 'Women vs. Median')
plt.show()

# %% [markdown]
# There plots looks to be pretty dense (we'll come back to this later).
#
# Let's practice creating some Histograms to explore distributions.

# %%
data_cols = ['Sample_size',
             'Median',
             'Employed',
             'Full_time',
             'ShareWomen',
             'Unemployment_rate',
             'Men',
             'Women']

fig = plt.figure(figsize = (15, 20))

for i in range(8):
    
    ax = fig.add_subplot(4, 2, i+1)
    ax.hist(recent_grads[data_cols[i]], bins = 15)
    
    value = data_cols[i].replace("_", " ").title()
    ax.set_title(value)

# %% [markdown]
# That's one way to do it. We can also do something like this...

# %%
ax = recent_grads['Sample_size'].hist(bins = 15, figsize = (5, 5), range = (0, 2000))
ax.set_title("Sample Size")
plt.show()

# %% [markdown]
# or this...

# %%
ax = recent_grads['Sample_size'].plot(kind = 'hist', title = "Sample Size", figsize = (5, 5))
plt.show()

# %% [markdown]
# From observing these distributions, some appaer close to a normal distribution (bell shape), while others are heavily skewed.
#
#
# We can also generate a `scatter matrix plot` which combines both scatter plots and histograms. Let's have a look.

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize = (10, 10))
plt.show()

# %% [markdown]
# We can also change the histogrames to kernal density estimations

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize = (15, 15), diagonal = 'kde')
plt.show()

# %% [markdown]
# Let's have a quick look at bar charts

# %%
recent_grads[:10]['ShareWomen'].plot(kind = 'bar', title = "Share of Women")
plt.show()

# %% [markdown]
# We can also do this...

# %%
recent_grads[:10]['ShareWomen'].plot.bar(title = "Share of Women")
plt.show()

# %% [markdown]
# or this...

# %%
recent_grads[:10].plot.bar(y = "ShareWomen", title = "Share of Women", legend = False)
plt.show()

# %% [markdown]
# We may wnat to assign some labels...

# %%
recent_grads[:10].plot.bar(y = "ShareWomen", x = "Major_category", title = "Share of Women", legend = False)
plt.show()

# %% [markdown]
# In reality, we would probably want to group this data and present it differently, like below...

# %%
major_groupby = recent_grads.groupby(['Major_category'])['ShareWomen'].mean().sort_values()
ax = major_groupby.plot(kind = 'barh', rot = 0, title = 'Share of Women by Major Category', figsize = (10, 10))
ax.set_ylabel("Major Category")
plt.show()

# %% [markdown]
# Let's look closer at the number of women and men in each major category

# %%
major_groupby = recent_grads.groupby(['Major_category'])['Women'].mean().sort_values()
ax = major_groupby.plot(kind = 'barh', rot = 0, title = 'No of Women by Major Category', figsize = (10, 10))
ax.set_ylabel("Major Category")
plt.show()

# %%
major_groupby = recent_grads.groupby(['Major_category'])['Men'].mean().sort_values()
ax = major_groupby.plot(kind = 'barh', rot = 0, title = 'No of Men by Major Category', figsize = (10, 10))
ax.set_ylabel("Major Category")
# Out:
# Text(0, 0.5, 'Major Category')

# %% [markdown]
# We might be better place these on the same figure, for an easier comparison. Let's have a look.

# %%
section = recent_grads[['Major_category', 'Men', 'Women']]
gender_category = section.groupby(['Major_category']).mean().sort_index().astype(int)
gender_category
# Out:
#                                        Men  Women
# Major_category
# Agriculture & Natural Resources       4484   3918
# Arts                                 16798  27842
# Biology & Life Science               13208  19210
# Business                             51373  48809
# Communications & Journalism          32980  65170
# Computers & Mathematics              18975   8207
# Education                             6470  28475
# Engineering                          14079   4457
# Health                                6293  32309
# Humanities & Liberal Arts            18189  29374
# Industrial Arts & Consumer Services  14825  18001
# Interdisciplinary                     2817   9479
# Law & Public Policy                  18225  17595
# Physical Sciences                     9539   9008
# Psychology & Social Work             10901  42543
# Social Science                       28537  30348

# %%
ax = gender_category.plot(kind = 'barh', figsize = (10, 10))
ax.set_title("Men & Women by Major Category")
ax.set_ylabel("Major Category")
ax.set_xlabel("Total")
plt.show()

# %% [markdown]
# Let's now have a look at median salaries and unemployment rate using boxplots & histograms. There's several ways we could do this.

# %%
recent_grads['Median'].hist(grid = False)
plt.show()

# %%
recent_grads['Unemployment_rate'].plot.hist(grid = False)
plt.show()

# %%
recent_grads[['Unemployment_rate', 'Median']].hist(grid = False, figsize = (15, 5))
plt.show()

# %%
fig = plt.figure(figsize = (15, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

ax1.boxplot(x = recent_grads['Unemployment_rate'])
ax1.set_title('Unemployment Rate')
ax1.set_ylabel('Rate of Unemployment')

ax2.boxplot(x = recent_grads['Median'])
ax2.set_title('Median Salary')
ax2.set_ylabel('Salary (Median)')

plt.show()

# %%
recent_grads.boxplot(column = 'Unemployment_rate')
plt.show()

# %%
recent_grads.boxplot(column = 'Median')
plt.show()

# %% [markdown]
# Use a hexagonal bin plot to visualize the columns that had dense scatter plots from earlier in the project. Let's do it slighly different than previously (borrowed from someone else's project).
#
# Let's also play around with the colours a bit.

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(20,20))
plt.subplots_adjust(hspace=.5)

recent_grads.plot(x = 'Sample_size', y = 'Median', kind = 'hexbin', ax = axes[0,0], gridsize=25, colormap = 'magma', rot=45, sharex = False)
recent_grads.plot(x = 'Sample_size', y = 'Unemployment_rate', kind = 'hexbin', ax = axes[0,1], gridsize=25, colormap = 'plasma', rot=45, sharex = False)
recent_grads.plot(x = 'Full_time', y = 'Median', kind = 'hexbin', ax = axes[1,0], gridsize=25, colormap = 'viridis', rot=45, sharex = False)
recent_grads.plot(x = 'ShareWomen', y = 'Unemployment_rate', kind = 'hexbin', ax = axes[1,1], gridsize=25, colormap = 'cividis', rot=45, sharex = False)
recent_grads.plot(x = 'Men', y = 'Median', kind = 'hexbin', ax = axes[2,0], gridsize=25, colormap = 'inferno', rot=45, sharex = False)
recent_grads.plot(x = 'Women', y = 'Median', kind = 'hexbin', ax = axes[2,1], gridsize=25, colormap = 'winter', rot=45, sharex = False)

plt.show()

# %% [markdown]
# That's all for now!!
